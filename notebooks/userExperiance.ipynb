# %%
import sys
import os

# Add the root directory to sys.path
sys.path.append(os.path.abspath('..'))

from scripts import userExperiance

# %%
userexp = userExperiance()
data = userexp.load_data()
data.head()
# Out:
#       Bearer Id           Start  Start ms             End  End ms  Dur. (ms)  \
# 0  7.349883e+18  4/25/2019 7:18     301.0  4/26/2019 9:58   184.0    96028.0
# 1  7.349883e+18  4/25/2019 7:18     560.0  4/26/2019 9:50    61.0    95538.0
# 2  1.311448e+19  4/25/2019 7:18      56.0  4/26/2019 7:04   543.0    85560.0
# 3  1.311448e+19  4/25/2019 7:18     416.0  4/26/2019 0:52   248.0    63247.0
# 4  1.311448e+19  4/25/2019 7:18     147.0  4/26/2019 2:56   605.0    70692.0
#
#            IMSI  MSISDN/Number          IMEI Last Location Name  ...  \
# 0  2.082014e+14   3.376162e+10  3.572241e+13            T54284C  ...
# 1  2.082017e+14   3.366788e+10  3.534721e+13            L10404A  ...
# 2  2.082014e+14   3.366680e+10  3.528021e+13            D11113A  ...
# 3  2.082019e+14   3.365909e+10  3.533181e+13            D74975B  ...
# 4  2.082009e+14   3.369926e+10  8.665320e+13            D42228C  ...
#
#    Youtube DL (Bytes)  Youtube UL (Bytes)  Netflix DL (Bytes)  \
# 0           6383316.0           3072574.0          16063073.0
# 1          14672384.0          10405420.0           1577604.0
# 2           4323259.0           5993411.0           7521703.0
# 3           7905356.0          12456412.0          13410261.0
# 4            358295.0          15955285.0          10917856.0
#
#    Netflix UL (Bytes)  Gaming DL (Bytes)  Gaming UL (Bytes)  Other DL (Bytes)  \
# 0           1230417.0        595212072.0          4106639.0       698087971.0
# 1          21375681.0        751042730.0          6820809.0       608377525.0
# 2          16010561.0         63254156.0          2133184.0       709081795.0
# 3           8732662.0        119535656.0         15936549.0       530023800.0
# 4          12366926.0        240388758.0         14593958.0       267516409.0
#
#    Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)
# 0         6811650.0        17143740.0       634334121.0
# 1          750973.0        43047147.0       782780736.0
# 2        12720150.0        39563946.0        77533465.0
# 3         1454427.0        42229659.0       150105314.0
# 4        16186133.0        62224358.0       263329850.0
#
# [5 rows x 55 columns]

# %%
userexp.agg_by_user()
# Out:
#         MSISDN/Number  Average TCP Retransmission  Average RTT  \
# 0        3.360100e+10                         NaN        23.00
# 1        3.360100e+10                         NaN        15.50
# 2        3.360100e+10                         NaN          NaN
# 3        3.360101e+10                         NaN        42.00
# 4        3.360101e+10                   4685416.0        29.75
# ...               ...                         ...          ...
# 106851   3.379000e+10                    109022.5        26.00
# 106852   3.379000e+10                         NaN        20.00
# 106853   3.197021e+12                         NaN          NaN
# 106854   3.370000e+14                         NaN          NaN
# 106855   8.823971e+14                         NaN          NaN
#
#                             Handset Type  Average Throughput
# 0         Huawei P20 Lite Huawei Nova 3E                38.0
# 1                 Apple iPhone 7 (A1778)                49.5
# 2                              undefined                48.5
# 3                Apple iPhone 5S (A1457)               124.0
# 4                Apple iPhone Se (A1723)             14211.0
# ...                                  ...                 ...
# 106851               Huawei Honor 9 Lite              5182.5
# 106852       Apple iPhone 8 Plus (A1897)                58.0
# 106853  Quectel Wireless. Quectel Ec25-E                 0.5
# 106854                  Huawei B525S-23A                16.5
# 106855  Quectel Wireless. Quectel Ec21-E                 1.0
#
# [106856 rows x 5 columns]

# %%
userexp.check_for_missing_values()
# Out:
#  Missing values count:
#  MSISDN/Number                     0
# Average TCP Retransmission    67565
# Average RTT                   18544
# Handset Type                      0
# Average Throughput                0
# dtype: int64
# missing values Percentage:
#  MSISDN/Number                  0.000000
# Average TCP Retransmission    45.043033
# Average RTT                   12.362584
# Handset Type                   0.000000
# Average Throughput             0.000000
# dtype: float64
# And here is the visual representation

# %%
userexp.remove_missing_values()

# %%
userexp.check_for_missing_values()
# Out:
#  Missing values count:
#  MSISDN/Number                 0
# Average TCP Retransmission    0
# Average RTT                   0
# Handset Type                  0
# Average Throughput            0
# dtype: int64
# missing values Percentage:
#  MSISDN/Number                 0.0
# Average TCP Retransmission    0.0
# Average RTT                   0.0
# Handset Type                  0.0
# Average Throughput            0.0
# dtype: float64
# And here is the visual representation

# %%
userexp.check_for_outliers_iqr_method()
# Out:
# Outliers detected in MSISDN/Number:
#  0         3.360100e+10
# 1         3.360100e+10
# 2         3.360100e+10
# 3         3.360101e+10
# 4         3.360101e+10
#               ...
# 106851    3.379000e+10
# 106852    3.379000e+10
# 106853    3.197021e+12
# 106854    3.370000e+14
# 106855    8.823971e+14
# Name: MSISDN/Number, Length: 16950, dtype: float64
# Outliers detected in Average TCP Retransmission:
#  65        101331837.0
# 139        29496174.0
# 170       126486595.5
# 637       109977030.0
# 924        25658716.5
#              ...
# 105751     59352648.0
# 105799     49715394.5
# 106133     60959806.0
# 106225     36762623.0
# 106272     56598274.5
# Name: Average TCP Retransmission, Length: 1862, dtype: float64
# Outliers detected in Average RTT:
#  20        247.0
# 47        180.5
# 89        145.5
# 90        375.5
# 98        255.5
#           ...
# 106727    724.5
# 106736    397.0
# 106754    251.5
# 106807    693.5
# 106811    149.5
# Name: Average RTT, Length: 5947, dtype: float64
# Outliers detected in Average Throughput:
#  40        31432.50
# 48        27105.25
# 59        26605.50
# 62        27399.25
# 69        49676.00
#             ...
# 106813    33016.00
# 106833    31604.00
# 106841    30076.50
# 106845    70656.00
# 106850    40769.75
# Name: Average Throughput, Length: 9520, dtype: float64

# %%
userexp.handle_outliers()

# %%
userexp.check_for_outliers_iqr_method()
# Out:
# No outliers detected in MSISDN/Number using IQR method.
# No outliers detected in Average TCP Retransmission using IQR method.
# No outliers detected in Average RTT using IQR method.
# No outliers detected in Average Throughput using IQR method.

# %%
userexp.compute_list_of_ten()
# Out:
# Top 10 TCP Values:
#  96632     2.415070e+07
# 86751     2.415070e+07
# 40378     2.415070e+07
# 40381     2.415070e+07
# 31684     2.415070e+07
# 40444     2.415070e+07
# 86713     2.415070e+07
# 40459     2.415070e+07
# 103153    2.415070e+07
# 86687     2.415070e+07
# Name: Average TCP Retransmission, dtype: float64
# Bottom 10 TCP Values:
#  23472     48.5
# 35618     54.0
# 19530     56.5
# 6359      64.0
# 96977     64.5
# 101404    67.0
# 13546     67.0
# 2177      71.5
# 27975     87.5
# 25863     88.0
# Name: Average TCP Retransmission, dtype: float64
# Most Frequent TCP Values:
#  Average TCP Retransmission
# 1.057965e+07    67565
# 2.415070e+07     1862
# 1.330000e+03       21
# 2.660000e+03       21
# 3.325000e+03       18
# 1.995000e+03       17
# 3.990000e+03       13
# 9.365000e+02        9
# 5.985000e+03        8
# 1.324000e+03        8
# Name: count, dtype: int64
#
# Top 10 RTT Values:
#  54326     139.190157
# 106807    139.190157
# 20        139.190157
# 54342     139.190157
# 86591     139.190157
# 106754    139.190157
# 54382     139.190157
# 98        139.190157
# 72662     139.190157
# 47        139.190157
# Name: Average RTT, dtype: float64
# Bottom 10 RTT Values:
#  44748    0.0
# 28878    0.0
# 39066    1.0
# 83396    2.0
# 36039    2.5
# 69662    3.0
# 21980    4.0
# 3882     4.5
# 74434    4.5
# 17863    5.0
# Name: Average RTT, dtype: float64
# Most Frequent RTT Values:
#  Average RTT
# 67.676063     18544
# 139.190157     5947
# 14.500000      2999
# 19.500000      2458
# 19.000000      1746
# 20.000000      1670
# 15.000000      1647
# 14.000000      1502
# 24.500000      1389
# 20.500000      1290
# Name: count, dtype: int64
#
# Top 10 Throughput Values:
#  78173     23588.8125
# 78122     23588.8125
# 62        23588.8125
# 78169     23588.8125
# 106795    23588.8125
# 78168     23588.8125
# 69        23588.8125
# 79        23588.8125
# 106813    23588.8125
# 78177     23588.8125
# Name: Average Throughput, dtype: float64
# Bottom 10 Throughput Values:
#  41354    0.0
# 15885    0.0
# 28745    0.0
# 45265    0.0
# 7196     0.0
# 63501    0.0
# 8439     0.0
# 94744    0.0
# 17033    0.0
# 1204     0.0
# Name: Average Throughput, dtype: float64
# Most Frequent Throughput Values:
#  Average Throughput
# 23588.8125    9520
# 7.5000        2872
# 31.5000       2138
# 48.5000       1094
# 45.0000       1062
# 49.0000       1025
# 48.0000        938
# 49.5000        918
# 44.5000        881
# 45.5000        864
# Name: count, dtype: int64
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:114: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_tcp.values, y=top_10_tcp.index, ax=axes[0, 0], palette="viridis")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:119: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bottom_10_tcp.values, y=bottom_10_tcp.index, ax=axes[0, 1], palette="viridis")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:124: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_freq_tcp.values, y=most_freq_tcp.index, ax=axes[0, 2], palette="viridis")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:129: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_rtt.values, y=top_10_rtt.index, ax=axes[1, 0], palette="magma")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:134: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bottom_10_rtt.values, y=bottom_10_rtt.index, ax=axes[1, 1], palette="magma")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:139: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_freq_rtt.values, y=most_freq_rtt.index, ax=axes[1, 2], palette="magma")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:144: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_throughput.values, y=top_10_throughput.index, ax=axes[2, 0], palette="coolwarm")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:149: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bottom_10_throughput.values, y=bottom_10_throughput.index, ax=axes[2, 1], palette="coolwarm")
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TWO\week-2\scripts\customerExperianceAnalysis.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_freq_throughput.values, y=most_freq_throughput.index, ax=axes[2, 2], palette="coolwarm")

# %%
userexp.Average_Throughput_per_Handset_Type()
# Out:
#                                            Handset Type  Average Throughput
# 0                            A-Link Telecom I. Cubot A5        11755.000000
# 1                     A-Link Telecom I. Cubot Note Plus         3349.500000
# 2                        A-Link Telecom I. Cubot Note S         4468.500000
# 3                          A-Link Telecom I. Cubot Nova        23588.812500
# 4                         A-Link Telecom I. Cubot Power        23588.812500
# ...                                                 ...                 ...
# 1389  Zte Zte Blade C2 Smartphone Android By Sfr Sta...           29.000000
# 1390                          Zyxel Communicat. Lte7460        23588.812500
# 1391                          Zyxel Communicat. Sbg3600        23588.812500
# 1392                    Zyxel Communicat. Zyxel Wah7706         1086.500000
# 1393                                          undefined         3618.594784
#
# [1394 rows x 2 columns]

# %% [markdown]
# Distribution of Average Throughput per Handset Type
#
# In the first graph, we see the distribution of average throughput per handset type. The histogram shows that the majority of the throughput values are concentrated at the lower end, with a significant number of data points around the 0 to 1000 kbps range. As the throughput increases, the frequency of data points decreases, with a long tail extending towards higher throughput values.
# Interpretation:
#
#     Skewed Distribution: The distribution is heavily right-skewed, indicating that most handset types experience lower average throughput, while only a few achieve high throughput values.
#     Possible Bottlenecks: The concentration of low throughput values suggests that there may be network or device-related bottlenecks affecting the performance of most handsets.
#     Outliers: The presence of a long tail could indicate the existence of outliers or special cases where certain handsets achieve significantly higher throughput, possibly due to better hardware, network conditions, or data usage patterns.

# %%
userexp.tcp_per_handset()
# Out:
#                                            Handset Type  \
# 0                            A-Link Telecom I. Cubot A5
# 1                     A-Link Telecom I. Cubot Note Plus
# 2                        A-Link Telecom I. Cubot Note S
# 3                          A-Link Telecom I. Cubot Nova
# 4                         A-Link Telecom I. Cubot Power
# ...                                                 ...
# 1389  Zte Zte Blade C2 Smartphone Android By Sfr Sta...
# 1390                          Zyxel Communicat. Lte7460
# 1391                          Zyxel Communicat. Sbg3600
# 1392                    Zyxel Communicat. Zyxel Wah7706
# 1393                                          undefined
#
#       Average TCP Retransmission
# 0                   1.057965e+07
# 1                   3.081065e+05
# 2                   2.070587e+07
# 3                   6.858500e+04
# 4                   4.020500e+03
# ...                          ...
# 1389                1.057965e+07
# 1390                2.063827e+07
# 1391                2.415070e+07
# 1392                1.057965e+07
# 1393                8.259586e+06
#
# [1394 rows x 2 columns]

# %% [markdown]
# Distribution of Average TCP Retransmission per Handset Type
#
# In the second graph, the distribution of average TCP retransmission per handset type is displayed. The histogram has a bimodal distribution with two prominent peaks. One peak occurs near zero, and another around a higher retransmission value, indicating two distinct groups in the dataset.
# Interpretation:
#
#     Bimodal Distribution: The bimodal nature suggests that there are two separate groups or behaviors in the dataset. One group of handset types experiences almost no retransmissions, while another group shows significantly higher retransmissions.
#     Network Reliability Issues: The high retransmission values in one group could indicate issues with network reliability or handset performance, leading to frequent retransmissions.
#     Zero Retransmissions: The high frequency of zero or near-zero retransmissions might indicate that for many handsets, the network conditions are optimal, resulting in minimal data packet loss.
#
# Overall, the visualizations suggest that the majority of handset types experience lower average throughput and are generally reliable with minimal retransmissions. However, there are outliers or special cases that warrant further investigation to improve network performance and user experience.
